# %% [markdown]
# # **Notebook 15 – Mini Assessment**

# %% [markdown]
# ## **Part 1 – Theory Questions**

# %% [markdown]
# **1. What is Statistics and why is it important in AI/ML?**

# %% [markdown]
# **2. What is the difference between Population and Sample?**

# %% [markdown]
# **3. What is the difference between Mean, Median, and Mode?**

# %% [markdown]
# **4. What is the difference between Variance and Standard Deviation?**

# %% [markdown]
# **5. What is IQR and how is it used to detect Outliers?**

# %% [markdown]
# **6. What is the difference between Quantitative and Qualitative Data?**

# %% [markdown]
# **7. What is Normal Distribution and what is the Empirical Rule?**

# %% [markdown]
# **8. What is the difference between Independent and Dependent Events?**

# %% [markdown]
# **9. What is Conditional Probability?**

# %% [markdown]
# **10. What is Bayes' Theorem?**

# %% [markdown]
# **11. What is the difference between Correlation and Covariance?**

# %% [markdown]
# **12. What is the difference between Pearson and Spearman Correlation?**

# %% [markdown]
# **13. What is an Outlier? What are the common methods used to detect it?**

# %% [markdown]
# **14. What is a Null Hypothesis and Alternative Hypothesis?**

# %% [markdown]
# **15. What is a p-value? What does p-value < 0.05 mean?**

# %% [markdown]
# **16. What is the difference between Type I and Type II Error?**

# %% [markdown]
# **17. What is the difference between One-tailed and Two-tailed Tests?**

# %% [markdown]
# **18. What is the difference between T-Test, Z-Test, and ANOVA?**

# %% [markdown]
# **19. What is Multicollinearity and what is VIF?**

# %% [markdown]
# **20. How is Statistics used in Machine Learning?**

# %% [markdown]
# ## **Part 2 – Coding Exercises**

# %% [markdown]
# **1. Write Python code to calculate Mean, Median, and Mode for a given dataset.**

# %% [markdown]
# **2. Write Python code to calculate Variance and Standard Deviation.**

# %% [markdown]
# **3. Write Python code to calculate Q1, Q3, and IQR.**

# %% [markdown]
# **4. Write Python code to calculate the 25th, 50th, and 75th Percentiles.**

# %% [markdown]
# **5. Write Python code to calculate Pearson Correlation between two variables.**

# %% [markdown]
# **6. Write Python code to calculate Spearman Correlation between two variables.**

# %% [markdown]
# **7. Write Python code to detect Outliers using the IQR Method.**

# %% [markdown]
# **8. Write Python code to calculate Z-Scores and identify possible Outliers.**

# %% [markdown]
# **9. Write Python code to perform a T-Test and display the p-value.**

# %% [markdown]
# **10. Write Python code to perform a Chi-Square Test.**

# %% [markdown]
# **11. Write Python code to perform ANOVA for three groups.**

# %% [markdown]
# **12. Write Python code to create a Correlation Matrix and display it using a Heatmap.**
